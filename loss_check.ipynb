# %%
import numpy as np
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib

# %%
data = np.load('epoch_loss_list.npz')

x=range(len(data['loss']))
y=data['loss'].reshape(-1)

plt.title('last loss cost : %f' %y[-1])
plt.plot(x,y)
plt.show()

print ('average : '+str(np.average(data['loss'])))
print ('min : '+str(np.min(data['loss'])))
# Out:
# average : 947.737
# min : 947.53

# %%
len(x)
# Out:
# 12

# %%
len(np.zeros([1,1,30]))
# Out:
# 1
